# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv("car.data")
data.head(5)
# Out:
#   buyimg  maint door persons lug_boot safety  class
# 0  vhigh  vhigh    2       2    small    low  unacc
# 1  vhigh  vhigh    2       2    small    med  unacc
# 2  vhigh  vhigh    2       2    small   high  unacc
# 3  vhigh  vhigh    2       2      med    low  unacc
# 4  vhigh  vhigh    2       2      med    med  unacc

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

# %%
buyimg = le.fit_transform(list(data["buyimg"]))

# %%
maint = le.fit_transform(list(data["maint"]))

# %%
door = le.fit_transform(list(data["door"]))

# %%
persons = le.fit_transform(list(data["persons"]))

# %%
lug_boot = le.fit_transform(list(data["lug_boot"]))

# %%
safety = le.fit_transform(list(data["safety"]))

# %%
cls = le.fit_transform(list(data["class"]))

# %%
print(buyimg)
# Out:
# [3 3 3 ... 1 1 1]

# %%
persons
# Out:
# array([0, 0, 0, ..., 2, 2, 2], dtype=int64)

# %%
X = list(zip(buyimg,maint,door,persons,lug_boot,safety))
y = list(cls)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(X,y,test_size = 0.2)

# %%
from sklearn.neighbors import KNeighborsClassifier
model = KNeighborsClassifier(n_neighbors=3)

# %%
model.fit(x_train,y_train)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=3, p=2,
#            weights='uniform')

# %%
acc = model.score(x_test,y_test)
acc
# Out:
# 0.8670520231213873

# %%
names = ["unacc","acc","good","vgood"]

# %%
Predicted = model.predict(x_test)
for x in range(len(x_test)):
    print("Predicted: ", names[Predicted[x]],"Data:",x_test[x],"actual:",names[y_test[x]])
    n = model.kneighbors([x_test[x]],7,True)
    print("N: ",n)
# Out:
# Predicted:  good Data: (1, 2, 1, 1, 2, 1) actual: good
# N:  (array([[1., 1., 1., 1., 1., 1., 1.]]), array([[ 791,  222, 1300,  496, 1240,  580,   74]], dtype=int64))
# Predicted:  unacc Data: (2, 3, 1, 1, 1, 0) actual: unacc
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.41421356, 1.41421356]]), array([[ 265,  271, 1362,  110,  451,  567, 1043]], dtype=int64))
# Predicted:  unacc Data: (0, 2, 1, 2, 0, 2) actual: unacc
# N:  (array([[1., 1., 1., 1., 1., 1., 1.]]), array([[1148,  854,  795, 1238,  888,  308, 1173]], dtype=int64))
# Predicted:  good Data: (0, 3, 3, 0, 2, 2) actual: good
# N:  (array([[1.        , 1.        , 1.        , 1.41421356, 1.41421356,
#         1.41421356, 1.41421356]]), array([[ 245, 1168, 1324,  562,  955,  481,  900]], dtype=int64))
# Predicted:  acc Data: (2, 2, 1, 2, 2, 0) actual: unacc
# N:  (array([[1., 1., 1., 1., 1., 1., 1.]]), array([[ 711,  926,  740,  159,  329, 1039,  121]], dtype=int64))
# Predicted:  unacc Data: (2, 3, 1, 1, 2, 0) actual: unacc
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.41421356, 1.41421356]]), array([[ 607,  897,    7,  363, 1039,  265,  586]], dtype=int64))
# Predicted:  unacc Data: (2, 0, 0, 2, 1, 0) actual: unacc
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.41421356]]), array([[594, 950, 462,  43, 637, 794, 585]], dtype=int64))
# Predicted:  good Data: (0, 3, 2, 1, 1, 0) actual: good
# N:  (array([[1., 1., 1., 1., 1., 1., 1.]]), array([[1041, 1196, 1244,  479,  661,  610,  283]], dtype=int64))
# Predicted:  vgood Data: (1, 0, 1, 2, 0, 0) actual: vgood
# N:  (array([[1., 1., 1., 1., 1., 1., 1.]]), array([[ 603,  114, 1322,  682,  825, 1218,  616]], dtype=int64))
# Predicted:  unacc Data: (2, 0, 3, 2, 1, 1) actual: good
# N:  (array([[1., 1., 1., 1., 1., 1., 1.]]), array([[1158,  288,   27,  748, 1373,  341, 1227]], dtype=int64))
# Predicted:  good Data: (0, 0, 1, 0, 1, 1) actual: good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.41421356]]), array([[ 528,  214,  613, 1280, 1064,  772,  783]], dtype=int64))
# Predicted:  good Data: (0, 2, 1, 0, 0, 0) actual: good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.41421356]]), array([[1185,  219, 1208,  112,  334,  978,    2]], dtype=int64))
# Predicted:  good Data: (0, 3, 2, 2, 0, 0) actual: good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.41421356, 1.41421356]]), array([[1041, 1082,   42,  595,  128,  852, 1146]], dtype=int64))
# Predicted:  good Data: (3, 3, 1, 2, 0, 2) actual: good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.41421356, 1.41421356]]), array([[ 892, 1123,   93, 1377,  979,  960,  856]], dtype=int64))
# Predicted:  good Data: (1, 3, 0, 2, 1, 0) actual: unacc
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.41421356]]), array([[ 261,  447,  560,  228, 1001, 1043,  758]], dtype=int64))
# Predicted:  good Data: (3, 1, 0, 1, 0, 2) actual: unacc
# N:  (array([[1., 1., 1., 1., 1., 1., 1.]]), array([[1037,  597, 1133, 1045, 1269,  532,  880]], dtype=int64))
# Predicted:  good Data: (2, 3, 1, 1, 2, 1) actual: good
# N:  (array([[1., 1., 1., 1., 1., 1., 1.]]), array([[ 627,  297,  770, 1362,  836,  734,  122]], dtype=int64))
# Predicted:  good Data: (2, 0, 1, 1, 2, 1) actual: good
# N:  (array([[1., 1., 1., 1., 1., 1., 1.]]), array([[812,  20, 844, 620, 301, 199, 312]], dtype=int64))
# Predicted:  unacc Data: (2, 0, 2, 1, 0, 2) actual: unacc
# N:  (array([[1., 1., 1., 1., 1., 1., 1.]]), array([[ 125,  928,  922,  420, 1021, 1273, 1241]], dtype=int64))
# Predicted:  unacc Data: (2, 0, 2, 1, 1, 0) actual: unacc
# N:  (array([[1., 1., 1., 1., 1., 1., 1.]]), array([[ 247, 1106,   56,  862, 1063,  142,  676]], dtype=int64))
# Predicted:  unacc Data: (1, 1, 2, 1, 1, 2) actual: acc
# N:  (array([[1., 1., 1., 1., 1., 1., 1.]]), array([[ 191,  802,  446,  654,  277, 1019,  695]], dtype=int64))
# Predicted:  good Data: (3, 0, 0, 0, 1, 1) actual: good
# N:  (array([[1., 1., 1., 1., 1., 1., 1.]]), array([[ 411,  517,  920, 1239,  877,  221,  690]], dtype=int64))
# Predicted:  good Data: (0, 2, 2, 0, 0, 0) actual: good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.41421356]]), array([[ 975, 1004, 1159,  601,  212,  126, 1197]], dtype=int64))
# Predicted:  good Data: (3, 1, 1, 0, 1, 2) actual: good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.41421356]]), array([[596, 375, 923, 826, 465, 535, 328]], dtype=int64))
# Predicted:  good Data: (0, 3, 0, 2, 0, 1) actual: good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.41421356,
#         1.41421356, 1.41421356]]), array([[ 251,  486,  553,  762,  447,  253, 1271]], dtype=int64))
# Predicted:  good Data: (3, 2, 1, 2, 2, 1) actual: good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.41421356, 1.41421356]]), array([[ 924, 1084,  711, 1177,  509,  373, 1151]], dtype=int64))
# Predicted:  good Data: (0, 2, 0, 0, 1, 2) actual: good
# N:  (array([[1., 1., 1., 1., 1., 1., 1.]]), array([[ 370, 1067,  718,  548,  624,  445, 1116]], dtype=int64))
# Predicted:  unacc Data: (2, 1, 1, 1, 2, 2) actual: unacc
# N:  (array([[1., 1., 1., 1., 1., 1., 1.]]), array([[ 313, 1047,  525,  199,  764,  812,  230]], dtype=int64))
# Predicted:  unacc Data: (2, 2, 1, 2, 1, 2) actual: unacc
# N:  (array([[1., 1., 1., 1., 1., 1., 1.]]), array([[1195,  139,  686,  590, 1033,   10,  692]], dtype=int64))
# Predicted:  good Data: (3, 3, 1, 0, 0, 2) actual: good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.41421356, 1.41421356]]), array([[ 892,   97,  931,  895,  238, 1090,  960]], dtype=int64))
# Predicted:  unacc Data: (2, 2, 3, 2, 0, 2) actual: unacc
# N:  (array([[1., 1., 1., 1., 1., 1., 1.]]), array([[ 643, 1182, 1343, 1312, 1180,  724,  117]], dtype=int64))
# Predicted:  good Data: (0, 0, 2, 0, 2, 2) actual: good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.41421356]]), array([[ 442,  429,  660, 1125,  694,  573, 1064]], dtype=int64))
# Predicted:  good Data: (2, 2, 1, 0, 0, 0) actual: good
# N:  (array([[1., 1., 1., 1., 1., 1., 1.]]), array([[  32,   71,  359, 1029,  565,  433,  476]], dtype=int64))
# Predicted:  good Data: (2, 2, 3, 1, 0, 2) actual: unacc
# N:  (array([[1., 1., 1., 1., 1., 1., 1.]]), array([[ 172,   85, 1065,  605,   13,  647,   81]], dtype=int64))
# Predicted:  good Data: (2, 2, 0, 0, 0, 0) actual: good
# N:  (array([[1., 1., 1., 1., 1., 1., 1.]]), array([[ 527,    2, 1255,  632,  872,  944, 1122]], dtype=int64))
# Predicted:  unacc Data: (3, 1, 3, 1, 1, 0) actual: unacc
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.41421356, 1.41421356]]), array([[  47,  655,  439,  710,  752, 1366, 1144]], dtype=int64))
# Predicted:  good Data: (1, 3, 0, 2, 2, 1) actual: good
# N:  (array([[1., 1., 1., 1., 1., 1., 1.]]), array([[1097, 1352,  958,  319, 1157,  228, 1163]], dtype=int64))
# Predicted:  good Data: (3, 1, 1, 0, 0, 2) actual: good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.41421356]]), array([[ 880, 1242, 1045,  328,  859,  238,  876]], dtype=int64))
# Predicted:  good Data: (3, 2, 0, 2, 1, 1) actual: good
# N:  (array([[1., 1., 1., 1., 1., 1., 1.]]), array([[924, 917,  70, 422, 902, 489,  72]], dtype=int64))
# Predicted:  good Data: (3, 2, 3, 1, 0, 1) actual: good
# N:  (array([[1., 1., 1., 1., 1., 1., 1.]]), array([[ 605,  811,  544,  374,  464,   49, 1167]], dtype=int64))
# Predicted:  good Data: (1, 1, 1, 0, 1, 0) actual: good
# N:  (array([[1., 1., 1., 1., 1., 1., 1.]]), array([[ 164, 1294, 1060, 1073,  292,  991,  621]], dtype=int64))
# Predicted:  good Data: (0, 3, 2, 2, 0, 2) actual: good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.41421356]]), array([[ 333,  198,  854,  290,  128, 1238,  999]], dtype=int64))
# Predicted:  good Data: (1, 2, 3, 1, 0, 1) actual: good
# N:  (array([[1., 1., 1., 1., 1., 1., 1.]]), array([[1032,   50,  414, 1044,  289,   85, 1012]], dtype=int64))
# Predicted:  good Data: (3, 1, 0, 2, 2, 0) actual: good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.41421356, 1.41421356]]), array([[1108,   14, 1237, 1151,  708,  769, 1381]], dtype=int64))
# Predicted:  good Data: (1, 1, 0, 1, 2, 1) actual: good
# N:  (array([[1., 1., 1., 1., 1., 1., 1.]]), array([[  17, 1156,  663,   11,  889,   96,  875]], dtype=int64))
# Predicted:  good Data: (0, 1, 3, 0, 2, 2) actual: good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.41421356]]), array([[ 694, 1168,  660,   57,  120, 1305,  508]], dtype=int64))
# Predicted:  good Data: (3, 1, 1, 2, 1, 1) actual: good
# N:  (array([[1., 1., 1., 1., 1., 1., 1.]]), array([[1177, 1219, 1058,  489,   83, 1330,  962]], dtype=int64))
# Predicted:  good Data: (3, 2, 2, 0, 2, 2) actual: good
# N:  (array([[1., 1., 1., 1., 1., 1., 1.]]), array([[ 427,  372, 1211,  444,  992,  745,  181]], dtype=int64))
# Predicted:  good Data: (2, 0, 0, 1, 1, 2) actual: good
# N:  (array([[1., 1., 1., 1., 1., 1., 1.]]), array([[ 904, 1031,  870,  266,  309,  585,  100]], dtype=int64))
# Predicted:  unacc Data: (0, 1, 1, 2, 2, 0) actual: unacc
# N:  (array([[1., 1., 1., 1., 1., 1., 1.]]), array([[1174,  406, 1016,  684,  739,  873, 1102]], dtype=int64))
# Predicted:  good Data: (3, 1, 3, 1, 1, 1) actual: good
# N:  (array([[1., 1., 1., 1., 1., 1., 1.]]), array([[  49,  886, 1013,  809,  840,  768, 1366]], dtype=int64))
# Predicted:  good Data: (3, 3, 0, 0, 1, 0) actual: good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.41421356]]), array([[1309, 1112, 1214, 1130, 1051,  567,  132]], dtype=int64))
# Predicted:  good Data: (0, 2, 2, 0, 1, 0) actual: good
# N:  (array([[1., 1., 1., 1., 1., 1., 1.]]), array([[1216, 1200, 1196,  661, 1056, 1197, 1302]], dtype=int64))
# Predicted:  good Data: (3, 0, 3, 0, 2, 1) actual: good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.41421356,
#         1.41421356, 1.41421356]]), array([[ 896,  397,    3,  158, 1254, 1162,  262]], dtype=int64))
# Predicted:  unacc Data: (3, 2, 0, 2, 0, 1) actual: good
# N:  (array([[1., 1., 1., 1., 1., 1., 1.]]), array([[ 295,  279, 1205,  369,  256, 1023,  376]], dtype=int64))
# Predicted:  good Data: (2, 2, 0, 2, 2, 2) actual: good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.41421356]]), array([[1103,  863, 1033,  590,   89,  805,  313]], dtype=int64))
# Predicted:  unacc Data: (1, 3, 2, 2, 1, 2) actual: unacc
# N:  (array([[1., 1., 1., 1., 1., 1., 1.]]), array([[ 250,  608,  985,   51,  290,  333, 1165]], dtype=int64))
# Predicted:  good Data: (1, 3, 3, 0, 0, 2) actual: good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.41421356, 1.41421356]]), array([[1100,  806, 1272,  562,    4,  384,   36]], dtype=int64))
# Predicted:  good Data: (0, 2, 3, 1, 2, 2) actual: good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.41421356,
#         1.41421356, 1.41421356]]), array([[ 572,  910, 1168,    5,   61, 1011, 1337]], dtype=int64))
# Predicted:  good Data: (2, 0, 1, 2, 1, 2) actual: unacc
# N:  (array([[1., 1., 1., 1., 1., 1., 1.]]), array([[ 692,  115, 1250, 1226,  233,  100,  309]], dtype=int64))
# Predicted:  good Data: (3, 0, 3, 1, 2, 1) actual: good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.41421356]]), array([[ 59, 840, 617, 935, 768, 513, 896]], dtype=int64))
# Predicted:  good Data: (3, 1, 0, 0, 2, 0) actual: good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.41421356,
#         1.41421356, 1.41421356]]), array([[  35,  241, 1326,  184,  366,  411,  690]], dtype=int64))
# Predicted:  good Data: (2, 1, 1, 2, 1, 1) actual: good
# N:  (array([[1., 1., 1., 1., 1., 1., 1.]]), array([[1250,   10, 1088,  339,  692,  677,  814]], dtype=int64))
# Predicted:  good Data: (1, 0, 0, 1, 2, 2) actual: unacc
# N:  (array([[1., 1., 1., 1., 1., 1., 1.]]), array([[ 728,  317, 1236, 1156, 1316,  458,   17]], dtype=int64))
# Predicted:  good Data: (1, 0, 1, 0, 2, 0) actual: good
# N:  (array([[1., 1., 1., 1., 1., 1., 1.]]), array([[292, 804, 387, 703, 482, 164, 800]], dtype=int64))
# Predicted:  unacc Data: (1, 0, 2, 1, 1, 2) actual: unacc
# N:  (array([[1., 1., 1., 1., 1., 1., 1.]]), array([[ 453, 1028,  928,  416,  881,   39,  402]], dtype=int64))
# Predicted:  good Data: (1, 3, 0, 1, 1, 0) actual: unacc
# N:  (array([[1., 1., 1., 1., 1., 1., 1.]]), array([[683, 263, 209, 543, 271, 510, 395]], dtype=int64))
# Predicted:  good Data: (2, 2, 0, 1, 2, 1) actual: good
# N:  (array([[1., 1., 1., 1., 1., 1., 1.]]), array([[ 701,  122, 1222,  627, 1085,  407,   89]], dtype=int64))
# Predicted:  good Data: (3, 3, 0, 0, 0, 1) actual: good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.41421356]]), array([[  31,  931,  906, 1309, 1214,  878,  731]], dtype=int64))
# Predicted:  good Data: (3, 1, 0, 1, 1, 0) actual: unacc
# N:  (array([[1., 1., 1., 1., 1., 1., 1.]]), array([[  14,  132,  484, 1052,  563, 1341,  184]], dtype=int64))
# Predicted:  good Data: (1, 3, 3, 0, 2, 0) actual: good
# N:  (array([[1.        , 1.        , 1.        , 1.41421356, 1.41421356,
#         1.41421356, 1.41421356]]), array([[ 101, 1053,  294,  195, 1094, 1225,  320]], dtype=int64))
# Predicted:  good Data: (3, 3, 1, 2, 2, 1) actual: good
# N:  (array([[1., 1., 1., 1., 1., 1., 1.]]), array([[ 641,  456,  361,  770,  297, 1311,  856]], dtype=int64))
# Predicted:  good Data: (3, 0, 1, 2, 0, 1) actual: good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.41421356]]), array([[1058,   83,  192, 1261,  285, 1355,  534]], dtype=int64))
# Predicted:  unacc Data: (0, 2, 0, 2, 1, 2) actual: good
# N:  (array([[1., 1., 1., 1., 1., 1., 1.]]), array([[1148,  511,  698,  548,  252,  795,  983]], dtype=int64))
# Predicted:  good Data: (0, 2, 2, 0, 0, 2) actual: good
# N:  (array([[1., 1., 1., 1., 1., 1., 1.]]), array([[ 365,  688,  127,   36, 1194,  975,  410]], dtype=int64))
# Predicted:  good Data: (3, 1, 2, 0, 0, 0) actual: good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.41421356]]), array([[ 270, 1368,  756, 1144,  342,  618,  905]], dtype=int64))
# Predicted:  unacc Data: (2, 2, 1, 1, 2, 0) actual: unacc
# N:  (array([[1., 1., 1., 1., 1., 1., 1.]]), array([[ 925, 1240,  122, 1285, 1081, 1291,  407]], dtype=int64))
# Predicted:  good Data: (3, 1, 1, 0, 0, 0) actual: good
# N:  (array([[1., 1., 1., 1., 1., 1., 1.]]), array([[ 905, 1029,   15,  476,  859,    6, 1262]], dtype=int64))
# Predicted:  unacc Data: (3, 2, 3, 1, 1, 0) actual: unacc
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.41421356, 1.41421356]]), array([[464, 918, 544, 237, 518, 655, 752]], dtype=int64))
# Predicted:  good Data: (0, 1, 0, 1, 2, 2) actual: good
# N:  (array([[1., 1., 1., 1., 1., 1., 1.]]), array([[ 239,  671,  663, 1156,  223, 1220, 1236]], dtype=int64))
# Predicted:  good Data: (3, 2, 0, 0, 0, 2) actual: good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.41421356, 1.41421356]]), array([[1329,  238,  178,  880,  906,  399,  944]], dtype=int64))
# Predicted:  good Data: (1, 3, 2, 0, 0, 2) actual: good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.41421356]]), array([[  66,  189,  127,  310,   36, 1210,  198]], dtype=int64))
# Predicted:  good Data: (1, 1, 3, 2, 1, 1) actual: good
# N:  (array([[1., 1., 1., 1., 1., 1., 1.]]), array([[939, 118, 288, 443,  23, 796, 134]], dtype=int64))
# Predicted:  good Data: (3, 3, 0, 2, 0, 2) actual: good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.41421356, 1.41421356]]), array([[ 376,  960,  971, 1304, 1023,   72,   31]], dtype=int64))
# Predicted:  good Data: (2, 3, 3, 0, 0, 0) actual: good
# N:  (array([[1., 1., 1., 1., 1., 1., 1.]]), array([[1095,   63, 1348,  582, 1344,  577,  306]], dtype=int64))
# Predicted:  good Data: (2, 3, 0, 0, 1, 2) actual: good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.41421356, 1.41421356]]), array([[1105,  891,  566, 1379, 1179,  226, 1213]], dtype=int64))
# Predicted:  good Data: (3, 1, 0, 0, 2, 2) actual: good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.41421356]]), array([[ 826, 1274, 1326,  596,  966,  981, 1135]], dtype=int64))
# Predicted:  good Data: (2, 0, 0, 1, 2, 0) actual: unacc
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.41421356]]), array([[ 594,   43, 1295,  581,  379,  519,  585]], dtype=int64))
# Predicted:  good Data: (2, 0, 3, 1, 2, 2) actual: good
# N:  (array([[1., 1., 1., 1., 1., 1., 1.]]), array([[ 943,  463,  646,  513, 1223,  415, 1068]], dtype=int64))
# Predicted:  good Data: (3, 1, 1, 0, 2, 0) actual: good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.41421356]]), array([[1135,  335,  366,  901,   15,  780,  116]], dtype=int64))
# Predicted:  good Data: (2, 1, 0, 0, 0, 2) actual: good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.41421356]]), array([[1242,  532,  644,  880,   12,  502,  761]], dtype=int64))
# Predicted:  good Data: (2, 3, 1, 2, 2, 2) actual: good
# N:  (array([[1., 1., 1., 1., 1., 1., 1.]]), array([[ 641, 1126,  590,  323,  770,  139,  836]], dtype=int64))
# Predicted:  good Data: (1, 1, 3, 0, 1, 1) actual: good
# N:  (array([[1., 1., 1., 1., 1., 1., 1.]]), array([[1252,  134,  587,  592,  347,  784,  227]], dtype=int64))
# Predicted:  good Data: (3, 3, 3, 0, 1, 2) actual: good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.41421356]]), array([[1288,  997,  176,  619,  157, 1149,  817]], dtype=int64))
# Predicted:  good Data: (2, 2, 1, 1, 2, 2) actual: unacc
# N:  (array([[1., 1., 1., 1., 1., 1., 1.]]), array([[ 590, 1300,  437,  664, 1195,  836,  122]], dtype=int64))
# Predicted:  good Data: (2, 0, 0, 1, 2, 1) actual: good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.41421356]]), array([[1192,  701,  904,  585,  506,   17,   43]], dtype=int64))
# Predicted:  unacc Data: (2, 2, 1, 1, 1, 0) actual: unacc
# N:  (array([[1., 1., 1., 1., 1., 1., 1.]]), array([[ 969, 1072,  359,  433,  740,  536, 1264]], dtype=int64))
# Predicted:  good Data: (3, 3, 0, 1, 2, 1) actual: good
# N:  (array([[1., 1., 1., 1., 1., 1., 1.]]), array([[1358,  297, 1311,  959,  715,  108,  731]], dtype=int64))
# Predicted:  vgood Data: (1, 1, 2, 2, 1, 0) actual: vgood
# N:  (array([[1., 1., 1., 1., 1., 1., 1.]]), array([[1263,  781,   23,  443,  970,  360,   58]], dtype=int64))
# Predicted:  good Data: (3, 3, 1, 1, 0, 0) actual: good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.41421356]]), array([[1279, 1253,  405,  725,  105,   45,   31]], dtype=int64))
# Predicted:  unacc Data: (1, 0, 3, 2, 2, 0) actual: unacc
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.41421356]]), array([[ 699, 1160,  460, 1134,  129,  421, 1062]], dtype=int64))
# Predicted:  good Data: (0, 3, 3, 2, 0, 2) actual: good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.41421356,
#         1.41421356, 1.41421356]]), array([[1203,  145,  384,  330,  583,  333,  128]], dtype=int64))
# Predicted:  good Data: (1, 3, 1, 0, 0, 1) actual: good
# N:  (array([[1., 1., 1., 1., 1., 1., 1.]]), array([[1276,  989,  189, 1059,   75,  303,  938]], dtype=int64))
# Predicted:  good Data: (1, 3, 1, 0, 2, 2) actual: good
# N:  (array([[1., 1., 1., 1., 1., 1., 1.]]), array([[ 240,  652,  552,  813,  908, 1127,  210]], dtype=int64))
# Predicted:  good Data: (1, 3, 3, 1, 2, 2) actual: good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.41421356]]), array([[ 763, 1161,  245,  320,  967,  550,  900]], dtype=int64))
# Predicted:  good Data: (0, 3, 3, 2, 1, 0) actual: good
# N:  (array([[1., 1., 1., 1., 1., 1., 1.]]), array([[ 583, 1187,  479, 1041,  595,  628,   22]], dtype=int64))
# Predicted:  unacc Data: (1, 3, 2, 2, 1, 0) actual: unacc
# N:  (array([[1., 1., 1., 1., 1., 1., 1.]]), array([[1041,   22,   53,   42,  531, 1165, 1244]], dtype=int64))
# Predicted:  good Data: (2, 1, 0, 0, 1, 2) actual: good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.41421356]]), array([[ 923,  761,  596,  266,  870,  566, 1049]], dtype=int64))
# Predicted:  good Data: (0, 0, 2, 1, 1, 2) actual: unacc
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.41421356, 1.41421356]]), array([[299, 442, 258, 914, 954, 524, 148]], dtype=int64))
# Predicted:  good Data: (2, 0, 0, 1, 0, 2) actual: unacc
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.41421356]]), array([[ 644,  532,  557, 1374, 1021, 1269,  953]], dtype=int64))
# Predicted:  good Data: (3, 0, 3, 0, 2, 0) actual: good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.41421356,
#         1.41421356, 1.41421356]]), array([[  59, 1076,  348,  215,  232,    3,  896]], dtype=int64))
# Predicted:  good Data: (3, 1, 2, 0, 0, 2) actual: good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.41421356]]), array([[ 535, 1202,  342,  291,  705, 1260,  328]], dtype=int64))
# Predicted:  unacc Data: (2, 2, 3, 1, 1, 0) actual: vgood
# N:  (array([[1., 1., 1., 1., 1., 1., 1.]]), array([[  33,  579, 1320, 1136,  790,  276, 1091]], dtype=int64))
# Predicted:  good Data: (0, 2, 0, 1, 0, 2) actual: unacc
# N:  (array([[1., 1., 1., 1., 1., 1., 1.]]), array([[ 370,  669,  888,  206,  548,  795, 1245]], dtype=int64))
# Predicted:  good Data: (0, 3, 0, 2, 2, 2) actual: good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.41421356]]), array([[ 729,  136,  511, 1163,  958,  698,  576]], dtype=int64))
# Predicted:  good Data: (2, 3, 3, 0, 1, 2) actual: good
# N:  (array([[1., 1., 1., 1., 1., 1., 1.]]), array([[1087,  562,  899,   60,  976,  806,  461]], dtype=int64))
# Predicted:  good Data: (0, 2, 3, 0, 2, 0) actual: good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.41421356, 1.41421356]]), array([[1056,   76,  368,  149, 1216,  523, 1364]], dtype=int64))
# Predicted:  good Data: (1, 3, 1, 1, 2, 1) actual: good
# N:  (array([[1., 1., 1., 1., 1., 1., 1.]]), array([[1127, 1332, 1083, 1157,  897,  495,  552]], dtype=int64))
# Predicted:  good Data: (0, 0, 2, 0, 1, 2) actual: good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.41421356]]), array([[ 982,  508,  402, 1280, 1015,  772, 1115]], dtype=int64))
# Predicted:  good Data: (2, 0, 3, 0, 2, 0) actual: good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.41421356]]), array([[1327,  547, 1117,  174,  397, 1128, 1318]], dtype=int64))
# Predicted:  good Data: (1, 2, 0, 0, 1, 0) actual: good
# N:  (array([[1., 1., 1., 1., 1., 1., 1.]]), array([[1294,  683,  103,  263,    2,  200,  839]], dtype=int64))
# Predicted:  good Data: (3, 1, 2, 1, 2, 2) actual: good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.41421356, 1.41421356]]), array([[ 181,  372, 1217, 1026, 1321,  373,  465]], dtype=int64))
# Predicted:  unacc Data: (3, 2, 1, 1, 0, 2) actual: unacc
# N:  (array([[1., 1., 1., 1., 1., 1., 1.]]), array([[ 892,  238,  357,  949, 1377, 1045,  178]], dtype=int64))
# Predicted:  good Data: (0, 1, 1, 1, 2, 2) actual: good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.41421356]]), array([[ 846, 1047, 1265,  524, 1074,  244,  193]], dtype=int64))
# Predicted:  unacc Data: (1, 2, 2, 2, 0, 2) actual: acc
# N:  (array([[1., 1., 1., 1., 1., 1., 1.]]), array([[ 529,  308, 1182,  290,  311,   51,  854]], dtype=int64))
# Predicted:  good Data: (0, 0, 1, 1, 1, 1) actual: good
# N:  (array([[1., 1., 1., 1., 1., 1., 1.]]), array([[1278,  258,  299, 1002,  280,  921, 1224]], dtype=int64))
# Predicted:  unacc Data: (3, 1, 3, 2, 0, 0) actual: unacc
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.41421356, 1.41421356]]), array([[ 655, 1289,   47,  651,  681,   49,  408]], dtype=int64))
# Predicted:  unacc Data: (2, 0, 1, 2, 0, 2) actual: unacc
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.41421356]]), array([[ 192,  420,  498, 1021, 1374,  388,  953]], dtype=int64))
# Predicted:  good Data: (3, 0, 3, 1, 2, 2) actual: good
# N:  (array([[1.        , 1.        , 1.41421356, 1.41421356, 1.41421356,
#         1.41421356, 1.41421356]]), array([[1217,  201,  840,  935, 1254,  262, 1162]], dtype=int64))
# Predicted:  good Data: (0, 2, 2, 0, 2, 1) actual: good
# N:  (array([[1., 1., 1., 1., 1., 1., 1.]]), array([[1011,  403,  149,  955, 1056,   61, 1302]], dtype=int64))
# Predicted:  good Data: (0, 3, 2, 1, 0, 0) actual: good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.41421356, 1.41421356]]), array([[1146,  601, 1159, 1079,  751, 1244,  661]], dtype=int64))
# Predicted:  good Data: (2, 1, 3, 2, 1, 1) actual: good
# N:  (array([[1., 1., 1., 1., 1., 1., 1.]]), array([[168, 809,  18, 339, 404, 886, 633]], dtype=int64))
# Predicted:  good Data: (2, 1, 2, 1, 1, 1) actual: good
# N:  (array([[1., 1., 1., 1., 1., 1., 1.]]), array([[886, 111, 913, 339, 541,  56, 197]], dtype=int64))
# Predicted:  good Data: (1, 1, 3, 0, 0, 2) actual: good
# N:  (array([[1., 1., 1., 1., 1., 1., 1.]]), array([[ 713, 1100,  485,  347,  933,  530,  784]], dtype=int64))
# Predicted:  unacc Data: (0, 0, 3, 2, 1, 2) actual: unacc
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.41421356]]), array([[1024, 1166,  820, 1233,  161,  954, 1000]], dtype=int64))
# Predicted:  good Data: (0, 1, 2, 0, 2, 0) actual: good
# N:  (array([[1., 1., 1., 1., 1., 1., 1.]]), array([[1200,  786,   76,  545, 1347,  205, 1357]], dtype=int64))
# Predicted:  good Data: (3, 3, 2, 2, 0, 1) actual: good
# N:  (array([[1., 1., 1., 1., 1., 1., 1.]]), array([[1042, 1359,  754, 1346,  119, 1123,   93]], dtype=int64))
# Predicted:  unacc Data: (0, 0, 3, 2, 0, 0) actual: unacc
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.41421356]]), array([[ 564, 1152,  468,  500,    8, 1062, 1334]], dtype=int64))
# Predicted:  vgood Data: (1, 0, 1, 1, 1, 0) actual: unacc
# N:  (array([[1., 1., 1., 1., 1., 1., 1.]]), array([[ 603, 1060, 1224,  921,  387,  164,  825]], dtype=int64))
# Predicted:  unacc Data: (0, 2, 2, 2, 0, 0) actual: unacc
# N:  (array([[1., 1., 1., 1., 1., 1., 1.]]), array([[ 355,  903, 1171,  589,  401,  852,  601]], dtype=int64))
# Predicted:  good Data: (3, 3, 0, 0, 0, 2) actual: good
# N:  (array([[1.        , 1.        , 1.41421356, 1.41421356, 1.41421356,
#         1.41421356, 1.41421356]]), array([[1379,  960,  178,  494, 1309, 1329,   31]], dtype=int64))
# Predicted:  unacc Data: (0, 1, 3, 2, 2, 2) actual: good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.41421356]]), array([[ 180, 1178,  730, 1233, 1024,  910,  275]], dtype=int64))
# Predicted:  good Data: (3, 1, 2, 1, 1, 1) actual: good
# N:  (array([[1., 1., 1., 1., 1., 1., 1.]]), array([[1321,  426, 1231, 1026,  439,  962, 1336]], dtype=int64))
# Predicted:  good Data: (0, 3, 3, 0, 0, 1) actual: good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.41421356]]), array([[ 425,  457,  481,    4,  947,  830, 1079]], dtype=int64))
# Predicted:  unacc Data: (2, 3, 0, 2, 0, 0) actual: unacc
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.41421356]]), array([[1043, 1235,    0,  864, 1110,  447,  872]], dtype=int64))
# Predicted:  good Data: (1, 3, 3, 0, 1, 1) actual: good
# N:  (array([[1., 1., 1., 1., 1., 1., 1.]]), array([[ 562, 1087, 1292,  481,  162,  101, 1055]], dtype=int64))
# Predicted:  good Data: (3, 0, 1, 2, 0, 2) actual: good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.41421356,
#         1.41421356, 1.41421356]]), array([[1132,  916, 1301, 1226,  625, 1058, 1045]], dtype=int64))
# Predicted:  good Data: (2, 1, 2, 0, 1, 0) actual: good
# N:  (array([[1., 1., 1., 1., 1., 1., 1.]]), array([[ 676,  756, 1318,   56,  197, 1368,  213]], dtype=int64))
# Predicted:  good Data: (0, 3, 3, 0, 1, 0) actual: good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.41421356]]), array([[ 101,  661,  481,  479,  425, 1216, 1094]], dtype=int64))
# Predicted:  unacc Data: (1, 2, 3, 2, 2, 1) actual: good
# N:  (array([[1., 1., 1., 1., 1., 1., 1.]]), array([[ 356,  559, 1333,  847,  871,  623,  170]], dtype=int64))
# Predicted:  good Data: (2, 0, 0, 0, 0, 0) actual: good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.41421356]]), array([[ 598,   48, 1122,  380, 1360,  578, 1077]], dtype=int64))
# Predicted:  unacc Data: (0, 1, 1, 2, 0, 0) actual: unacc
# N:  (array([[1., 1., 1., 1., 1., 1., 1.]]), array([[1298,  589,  298,  903,  739, 1218, 1322]], dtype=int64))
# Predicted:  good Data: (0, 0, 1, 0, 1, 0) actual: good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.41421356]]), array([[ 164,  800,  884,  783,  921,  351, 1376]], dtype=int64))
# Predicted:  good Data: (1, 3, 1, 1, 0, 2) actual: unacc
# N:  (array([[1., 1., 1., 1., 1., 1., 1.]]), array([[1378,  569, 1296,   54,  187,  189,  303]], dtype=int64))
# Predicted:  good Data: (1, 1, 0, 0, 1, 2) actual: good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.41421356]]), array([[ 412, 1282,  259,  894,  502,  624,  466]], dtype=int64))
# Predicted:  good Data: (2, 1, 3, 0, 1, 0) actual: good
# N:  (array([[1., 1., 1., 1., 1., 1., 1.]]), array([[ 174,  587, 1117, 1091, 1141,  710,  778]], dtype=int64))
# Predicted:  vgood Data: (2, 1, 3, 1, 1, 0) actual: vgood
# N:  (array([[1., 1., 1., 1., 1., 1., 1.]]), array([[ 886, 1101,  766,  404,  142,  418,   56]], dtype=int64))
# Predicted:  good Data: (2, 3, 2, 1, 2, 0) actual: unacc
# N:  (array([[1., 1., 1., 1., 1., 1., 1.]]), array([[1285,  634,  750,  700,  282,  110,  832]], dtype=int64))
# Predicted:  good Data: (2, 0, 3, 0, 1, 2) actual: good
# N:  (array([[1., 1., 1., 1., 1., 1., 1.]]), array([[ 943,  262,   65,  747,  390, 1223,  430]], dtype=int64))
# Predicted:  good Data: (3, 3, 1, 2, 1, 2) actual: good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.41421356]]), array([[971, 856,  73, 139, 641, 893,  72]], dtype=int64))
# Predicted:  good Data: (1, 3, 2, 2, 2, 2) actual: good
# N:  (array([[1., 1., 1., 1., 1., 1., 1.]]), array([[1161,  323,  179, 1126,  763,  448,  454]], dtype=int64))
# Predicted:  good Data: (0, 1, 3, 1, 2, 1) actual: good
# N:  (array([[1., 1., 1., 1., 1., 1., 1.]]), array([[1371, 1257,  599,  730,  807,    1,  120]], dtype=int64))
# Predicted:  good Data: (1, 2, 0, 2, 1, 1) actual: good
# N:  (array([[1., 1., 1., 1., 1., 1., 1.]]), array([[ 182,  560, 1097,  252,  591,  983, 1189]], dtype=int64))
# Predicted:  vgood Data: (1, 0, 2, 1, 0, 0) actual: vgood
# N:  (array([[1., 1., 1., 1., 1., 1., 1.]]), array([[ 554, 1063,  977,  114,  171, 1215,  603]], dtype=int64))
# Predicted:  unacc Data: (0, 1, 2, 1, 0, 0) actual: unacc
# N:  (array([[1., 1., 1., 1., 1., 1., 1.]]), array([[ 736, 1353,  986,  903,  126, 1215,  298]], dtype=int64))
# Predicted:  good Data: (2, 1, 3, 0, 2, 1) actual: good
# N:  (array([[1., 1., 1., 1., 1., 1., 1.]]), array([[ 397,  896,  778,  934, 1349,    9,  174]], dtype=int64))
# Predicted:  good Data: (3, 0, 1, 1, 1, 1) actual: good
# N:  (array([[1., 1., 1., 1., 1., 1., 1.]]), array([[ 962,  788, 1113,  620,  285, 1239,  221]], dtype=int64))
# Predicted:  unacc Data: (0, 0, 0, 2, 0, 0) actual: unacc
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.41421356]]), array([[ 682,  224, 1007, 1298,  987, 1322,  419]], dtype=int64))
# Predicted:  good Data: (0, 2, 0, 2, 1, 0) actual: unacc
# N:  (array([[1., 1., 1., 1., 1., 1., 1.]]), array([[1170, 1365, 1339,  560,  983,  152,  186]], dtype=int64))
# Predicted:  unacc Data: (2, 3, 3, 1, 0, 2) actual: unacc
# N:  (array([[1., 1., 1., 1., 1., 1., 1.]]), array([[  60, 1272, 1180,  204,  141,  806, 1104]], dtype=int64))
# Predicted:  good Data: (3, 3, 1, 1, 1, 0) actual: good
# N:  (array([[1., 1., 1., 1., 1., 1., 1.]]), array([[1112,  190,  363,  144, 1130,  593, 1072]], dtype=int64))
# Predicted:  good Data: (1, 1, 1, 2, 0, 1) actual: good
# N:  (array([[1., 1., 1., 1., 1., 1., 1.]]), array([[ 616,  677,  865,  849,  389, 1218,   79]], dtype=int64))
# Predicted:  good Data: (0, 2, 0, 2, 0, 1) actual: good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.41421356]]), array([[1189, 1173, 1170,  795,  983,  419,  378]], dtype=int64))
# Predicted:  unacc Data: (2, 3, 1, 1, 0, 0) actual: unacc
# N:  (array([[1., 1., 1., 1., 1., 1., 1.]]), array([[ 864,   52, 1145, 1315,   32,  433,    0]], dtype=int64))
# Predicted:  good Data: (3, 3, 0, 2, 2, 2) actual: good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.41421356, 1.41421356]]), array([[ 971,  641,  863, 1311, 1358,   72,  902]], dtype=int64))
# Predicted:  good Data: (2, 1, 1, 0, 2, 0) actual: good
# N:  (array([[1., 1., 1., 1., 1., 1., 1.]]), array([[1081, 1291,  213, 1318,   41,  371,  241]], dtype=int64))
# Predicted:  good Data: (3, 0, 3, 1, 1, 2) actual: good
# N:  (array([[1., 1., 1., 1., 1., 1., 1.]]), array([[ 768, 1223, 1013,  516, 1050,  262,  843]], dtype=int64))
# Predicted:  unacc Data: (0, 0, 2, 2, 1, 0) actual: unacc
# N:  (array([[1., 1., 1., 1., 1., 1., 1.]]), array([[1263,  743,  431, 1062, 1152,  970,  138]], dtype=int64))
# Predicted:  unacc Data: (1, 0, 0, 1, 0, 2) actual: unacc
# N:  (array([[1., 1., 1., 1., 1., 1., 1.]]), array([[ 493, 1199,  436,  693,  635,  458,  362]], dtype=int64))
# Predicted:  good Data: (1, 1, 0, 0, 1, 1) actual: good
# N:  (array([[1., 1., 1., 1., 1., 1., 1.]]), array([[367, 621, 991, 889, 952, 466, 875]], dtype=int64))
# Predicted:  good Data: (1, 2, 3, 0, 2, 0) actual: good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.41421356]]), array([[ 523,  268,  260,  672,  741, 1036, 1292]], dtype=int64))
# Predicted:  good Data: (0, 1, 3, 0, 0, 0) actual: good
# N:  (array([[1., 1., 1., 1., 1., 1., 1.]]), array([[986, 212,  19, 816, 126, 941, 726]], dtype=int64))
# Predicted:  good Data: (3, 0, 0, 0, 2, 0) actual: good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.41421356,
#         1.41421356, 1.41421356]]), array([[ 379,  581,  366,  690, 1326,  116,  678]], dtype=int64))
# Predicted:  good Data: (3, 3, 2, 0, 0, 2) actual: good
# N:  (array([[1.        , 1.        , 1.        , 1.41421356, 1.41421356,
#         1.41421356, 1.41421356]]), array([[1288,  176, 1210,   97,  892,  931,  895]], dtype=int64))
# Predicted:  acc Data: (1, 0, 0, 2, 1, 0) actual: unacc
# N:  (array([[1., 1., 1., 1., 1., 1., 1.]]), array([[ 540, 1340, 1007,  825,  682,  829,  822]], dtype=int64))
# Predicted:  good Data: (2, 1, 2, 1, 2, 2) actual: unacc
# N:  (array([[1., 1., 1., 1., 1., 1., 1.]]), array([[ 656,  664,  541,  111,  415, 1068, 1143]], dtype=int64))
# Predicted:  good Data: (3, 3, 1, 0, 1, 1) actual: good
# N:  (array([[1., 1., 1., 1., 1., 1., 1.]]), array([[ 912,  144,  895, 1112,  931,  650, 1309]], dtype=int64))
# Predicted:  good Data: (3, 2, 3, 0, 1, 0) actual: good
# N:  (array([[1., 1., 1., 1., 1., 1., 1.]]), array([[ 710, 1091, 1351,  749,  584,  817, 1075]], dtype=int64))
# Predicted:  good Data: (2, 0, 0, 0, 2, 2) actual: good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.41421356]]), array([[1192,  870,  904,  966,  831, 1316,  312]], dtype=int64))
# Predicted:  good Data: (2, 2, 0, 0, 0, 2) actual: good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.41421356,
#         1.41421356, 1.41421356]]), array([[ 566,   88, 1369,  944,  532, 1242,   12]], dtype=int64))
# Predicted:  vgood Data: (2, 2, 1, 2, 0, 0) actual: vgood
# N:  (array([[1., 1., 1., 1., 1., 1., 1.]]), array([[ 433,  858,  996,  864,  167,  740, 1110]], dtype=int64))
# Predicted:  good Data: (3, 2, 3, 1, 2, 0) actual: unacc
# N:  (array([[1., 1., 1., 1., 1., 1., 1.]]), array([[1119, 1136,  104,   29, 1351,  269,  752]], dtype=int64))
# Predicted:  good Data: (2, 1, 2, 0, 1, 2) actual: good
# N:  (array([[1., 1., 1., 1., 1., 1., 1.]]), array([[  65,  535, 1260, 1143,  430,  197,  923]], dtype=int64))
# Predicted:  unacc Data: (0, 1, 3, 2, 2, 0) actual: unacc
# N:  (array([[1., 1., 1., 1., 1., 1., 1.]]), array([[ 684,  615, 1134,  730, 1371,  129,  994]], dtype=int64))
# Predicted:  good Data: (1, 3, 3, 2, 2, 1) actual: good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.41421356]]), array([[ 803,  763, 1221,  320,  738,  454, 1332]], dtype=int64))
# Predicted:  good Data: (3, 1, 2, 0, 2, 1) actual: good
# N:  (array([[1., 1., 1., 1., 1., 1., 1.]]), array([[1135, 1321,    3,  181,  335, 1336,  896]], dtype=int64))
# Predicted:  good Data: (0, 1, 3, 1, 2, 2) actual: good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.41421356,
#         1.41421356, 1.41421356]]), array([[1142,  244,   82, 1190,  694,  442, 1019]], dtype=int64))
# Predicted:  good Data: (3, 0, 0, 0, 2, 1) actual: good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.41421356,
#         1.41421356, 1.41421356]]), array([[ 678, 1192, 1326,  966, 1186,  690,  221]], dtype=int64))
# Predicted:  good Data: (0, 2, 1, 1, 2, 2) actual: good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.41421356]]), array([[  37,  671,  385,   74, 1300,  515, 1116]], dtype=int64))
# Predicted:  good Data: (3, 0, 2, 2, 1, 2) actual: good
# N:  (array([[1., 1., 1., 1., 1., 1., 1.]]), array([[1132,  843,  413,  516, 1226,  107,  680]], dtype=int64))
# Predicted:  good Data: (1, 0, 3, 0, 1, 2) actual: good
# N:  (array([[1., 1., 1., 1., 1., 1., 1.]]), array([[ 347,   39,  402, 1017,  933,  227, 1015]], dtype=int64))
# Predicted:  good Data: (0, 0, 2, 1, 1, 0) actual: unacc
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.41421356]]), array([[ 351,  921, 1129,  977,  258, 1353,  767]], dtype=int64))
# Predicted:  unacc Data: (3, 2, 1, 2, 1, 0) actual: unacc
# N:  (array([[1., 1., 1., 1., 1., 1., 1.]]), array([[1219,  740,  711,  858, 1072,  593,   70]], dtype=int64))
# Predicted:  unacc Data: (3, 2, 0, 2, 2, 0) actual: good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.41421356]]), array([[ 70, 711, 924, 381, 828, 329, 108]], dtype=int64))
# Predicted:  good Data: (0, 3, 0, 2, 1, 1) actual: good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.41421356]]), array([[ 228,  261,  511, 1271, 1163,  983,  501]], dtype=int64))
# Predicted:  unacc Data: (0, 0, 2, 1, 2, 0) actual: unacc
# N:  (array([[1., 1., 1., 1., 1., 1., 1.]]), array([[ 936, 1114,  786,  743, 1357,  133, 1376]], dtype=int64))
# Predicted:  good Data: (3, 1, 0, 1, 2, 0) actual: unacc
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.41421356, 1.41421356]]), array([[ 581,  901,  769,  828, 1295,  287, 1380]], dtype=int64))
# Predicted:  unacc Data: (2, 0, 1, 1, 2, 0) actual: unacc
# N:  (array([[1., 1., 1., 1., 1., 1., 1.]]), array([[ 287,  387, 1081,  862,  247,  798,   41]], dtype=int64))
# Predicted:  unacc Data: (0, 1, 0, 2, 0, 2) actual: unacc
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.41421356]]), array([[669, 823, 702, 714, 419, 795, 635]], dtype=int64))
# Predicted:  unacc Data: (1, 2, 0, 2, 0, 2) actual: acc
# N:  (array([[1., 1., 1., 1., 1., 1., 1.]]), array([[1245,  337,  308,  714,  252,  795, 1189]], dtype=int64))
# Predicted:  good Data: (2, 3, 0, 0, 0, 2) actual: good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.41421356,
#         1.41421356, 1.41421356]]), array([[ 878,  879,   97,  868,  566,  824, 1105]], dtype=int64))
# Predicted:  good Data: (3, 0, 0, 2, 1, 0) actual: good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.41421356]]), array([[ 533, 1108,  534,   44,  484,   14, 1261]], dtype=int64))
# Predicted:  good Data: (3, 2, 1, 0, 1, 2) actual: good
# N:  (array([[1., 1., 1., 1., 1., 1., 1.]]), array([[ 895, 1118,  745,  238,  650,  357, 1329]], dtype=int64))
# Predicted:  good Data: (1, 0, 0, 0, 1, 0) actual: good
# N:  (array([[1., 1., 1., 1., 1., 1., 1.]]), array([[466, 164, 829, 578, 991, 884, 703]], dtype=int64))
# Predicted:  good Data: (1, 3, 2, 0, 0, 1) actual: good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.41421356, 1.41421356]]), array([[ 162,  457,  837,  396,  153, 1146, 1159]], dtype=int64))
# Predicted:  good Data: (1, 3, 0, 2, 0, 2) actual: unacc
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.41421356]]), array([[1147,  762,   54,  187,  251, 1304,  670]], dtype=int64))
# Predicted:  unacc Data: (0, 0, 2, 1, 0, 0) actual: unacc
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.41421356, 1.41421356]]), array([[1035, 1152, 1066, 1124,    8,  921,  603]], dtype=int64))
# Predicted:  good Data: (0, 1, 0, 2, 1, 1) actual: good
# N:  (array([[1., 1., 1., 1., 1., 1., 1.]]), array([[ 702, 1306,  612, 1229,   62,  419,  526]], dtype=int64))
# Predicted:  good Data: (3, 0, 3, 0, 2, 2) actual: good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.41421356,
#         1.41421356, 1.41421356]]), array([[ 943, 1254, 1162,  262,  896,  438,  424]], dtype=int64))
# Predicted:  good Data: (3, 0, 3, 1, 1, 0) actual: good
# N:  (array([[1., 1., 1., 1., 1., 1., 1.]]), array([[ 215,  142,   59, 1099, 1191,  768,  940]], dtype=int64))
# Predicted:  good Data: (0, 3, 3, 0, 1, 2) actual: good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.41421356]]), array([[   4,   80,  481, 1057,  562, 1209,  428]], dtype=int64))
# Predicted:  good Data: (0, 3, 3, 1, 2, 2) actual: good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.41421356,
#         1.41421356, 1.41421356]]), array([[ 151,  490, 1057,  900,  738,  428, 1203]], dtype=int64))
# Predicted:  good Data: (3, 2, 2, 2, 1, 1) actual: good
# N:  (array([[1., 1., 1., 1., 1., 1., 1.]]), array([[1370,  441,  119, 1284,  426,  704, 1258]], dtype=int64))
# Predicted:  good Data: (3, 2, 2, 0, 1, 1) actual: good
# N:  (array([[1., 1., 1., 1., 1., 1., 1.]]), array([[1336,  749,  817, 1211,  639,  575,  650]], dtype=int64))
# Predicted:  good Data: (2, 2, 1, 2, 2, 1) actual: good
# N:  (array([[1., 1., 1., 1., 1., 1., 1.]]), array([[770, 496, 122, 590,  89,  10, 814]], dtype=int64))
# Predicted:  good Data: (0, 2, 1, 0, 0, 2) actual: good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.41421356]]), array([[860, 370, 888, 334, 718, 331, 274]], dtype=int64))
# Predicted:  good Data: (2, 1, 0, 2, 0, 1) actual: good
# N:  (array([[1., 1., 1., 1., 1., 1., 1.]]), array([[394, 865, 349, 279, 723, 295, 677]], dtype=int64))
# Predicted:  good Data: (3, 0, 3, 2, 0, 0) actual: good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.41421356, 1.41421356]]), array([[ 857, 1048, 1099,  940,  131,  504,  417]], dtype=int64))
# Predicted:  good Data: (1, 0, 0, 0, 1, 2) actual: good
# N:  (array([[1., 1., 1., 1., 1., 1., 1.]]), array([[ 466,  870,  458, 1115,  211,  493, 1316]], dtype=int64))
# Predicted:  good Data: (3, 1, 3, 1, 2, 2) actual: good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.41421356]]), array([[1013, 1162, 1068,  840,  344,  514,  896]], dtype=int64))
# Predicted:  good Data: (3, 0, 2, 1, 0, 2) actual: good
# N:  (array([[1., 1., 1., 1., 1., 1., 1.]]), array([[1050, 1132,  291,  175, 1202,  843,  916]], dtype=int64))
# Predicted:  good Data: (0, 2, 0, 1, 2, 1) actual: good
# N:  (array([[1., 1., 1., 1., 1., 1., 1.]]), array([[1184,  663, 1069,  501,   74,  671,  791]], dtype=int64))
# Predicted:  good Data: (0, 3, 0, 1, 0, 1) actual: good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.41421356, 1.41421356]]), array([[ 570,  253,  206, 1271,  338, 1276,  622]], dtype=int64))
# Predicted:  unacc Data: (2, 1, 3, 2, 2, 0) actual: acc
# N:  (array([[1., 1., 1., 1., 1., 1., 1.]]), array([[1160,  432,  766,  340,  377,  633,  404]], dtype=int64))
# Predicted:  good Data: (0, 1, 1, 2, 0, 1) actual: good
# N:  (array([[1., 1., 1., 1., 1., 1., 1.]]), array([[ 419, 1173, 1306, 1275, 1111,  666,  823]], dtype=int64))
# Predicted:  unacc Data: (0, 0, 2, 2, 1, 2) actual: unacc
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.41421356, 1.41421356]]), array([[1078,  416,  721,  968,  431,  499,  115]], dtype=int64))
# Predicted:  good Data: (3, 1, 2, 1, 0, 1) actual: good
# N:  (array([[1., 1., 1., 1., 1., 1., 1.]]), array([[ 146,  408,  291,   49, 1144,  175,  342]], dtype=int64))
# Predicted:  good Data: (0, 3, 1, 1, 1, 1) actual: good
# N:  (array([[1., 1., 1., 1., 1., 1., 1.]]), array([[ 495,  253, 1271, 1109,  383,   68, 1083]], dtype=int64))
# Predicted:  unacc Data: (1, 3, 3, 2, 0, 2) actual: unacc
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.41421356]]), array([[ 163,  250, 1182, 1272,  290, 1180,   50]], dtype=int64))
# Predicted:  good Data: (0, 1, 1, 0, 2, 1) actual: good
# N:  (array([[1., 1., 1., 1., 1., 1., 1.]]), array([[ 846, 1372,  155,  613, 1265, 1064,  205]], dtype=int64))
# Predicted:  unacc Data: (1, 0, 0, 1, 0, 0) actual: vgood
# N:  (array([[1., 1., 1., 1., 1., 1., 1.]]), array([[ 578,  603,  224,  682, 1034,  436,  829]], dtype=int64))
# Predicted:  good Data: (0, 0, 1, 2, 1, 1) actual: good
# N:  (array([[1., 1., 1., 1., 1., 1., 1.]]), array([[1078,  431, 1306,  526,  138,  980,  666]], dtype=int64))
# Predicted:  good Data: (0, 3, 3, 0, 2, 0) actual: good
# N:  (array([[1.        , 1.41421356, 1.41421356, 1.41421356, 1.41421356,
#         1.41421356, 1.41421356]]), array([[1225,  481,  294,  955,  101,  479,  900]], dtype=int64))
# Predicted:  unacc Data: (1, 0, 3, 1, 2, 0) actual: unacc
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.41421356]]), array([[ 775, 1128, 1114,  102,  133,  547, 1129]], dtype=int64))
# Predicted:  good Data: (1, 2, 3, 0, 0, 0) actual: good
# N:  (array([[1., 1., 1., 1., 1., 1., 1.]]), array([[ 915, 1344, 1032,   19,  741, 1004,  212]], dtype=int64))
# Predicted:  good Data: (2, 1, 0, 0, 2, 2) actual: good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.41421356, 1.41421356]]), array([[ 764, 1282, 1049, 1010,  230,  761,  923]], dtype=int64))
# Predicted:  good Data: (1, 0, 1, 0, 0, 2) actual: good
# N:  (array([[1., 1., 1., 1., 1., 1., 1.]]), array([[1283,  207, 1199,  493, 1115,  948,  746]], dtype=int64))
# Predicted:  good Data: (0, 3, 1, 0, 1, 2) actual: good
# N:  (array([[1., 1., 1., 1., 1., 1., 1.]]), array([[  68,  813,  383,  718,  331, 1067,  210]], dtype=int64))
# Predicted:  good Data: (0, 0, 0, 2, 0, 2) actual: unacc
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.41421356, 1.41421356]]), array([[169, 499, 987, 362, 693, 714, 669]], dtype=int64))
# ...
#         1.41421356, 1.41421356]]), array([[  44,  349, 1301,  534,  295, 1058, 1261]], dtype=int64))
# Predicted:  unacc Data: (2, 2, 0, 1, 2, 2) actual: unacc
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.41421356]]), array([[ 226,  707, 1010,  984,  230,  208, 1274]], dtype=int64))
# Predicted:  vgood Data: (2, 1, 0, 2, 0, 0) actual: vgood
# N:  (array([[1., 1., 1., 1., 1., 1., 1.]]), array([[ 614,  257,  950, 1110,  167,   21,  794]], dtype=int64))
# Predicted:  good Data: (0, 2, 0, 1, 0, 1) actual: good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.41421356, 1.41421356]]), array([[1069,  497,  378, 1367,  188,  370,  219]], dtype=int64))
# Predicted:  good Data: (0, 3, 1, 2, 2, 0) actual: good
# N:  (array([[1., 1., 1., 1., 1., 1., 1.]]), array([[177, 716,  92, 604, 409, 818, 753]], dtype=int64))
# Predicted:  acc Data: (1, 1, 2, 1, 1, 0) actual: vgood
# N:  (array([[1., 1., 1., 1., 1., 1., 1.]]), array([[1215, 1353,  977, 1101, 1073,  202, 1060]], dtype=int64))
# Predicted:  good Data: (3, 2, 3, 2, 1, 2) actual: unacc
# N:  (array([[1., 1., 1., 1., 1., 1., 1.]]), array([[1325,  724,  441,  932,  503, 1312,  704]], dtype=int64))
# Predicted:  good Data: (0, 2, 1, 0, 1, 0) actual: good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.41421356]]), array([[ 839,  733,  274, 1294,  150, 1040,  219]], dtype=int64))
# Predicted:  good Data: (1, 0, 3, 0, 0, 1) actual: good
# N:  (array([[1., 1., 1., 1., 1., 1., 1.]]), array([[ 286,  227,  933, 1267,  784,  665,  942]], dtype=int64))
# Predicted:  good Data: (2, 3, 3, 2, 1, 1) actual: good
# N:  (array([[1., 1., 1., 1., 1., 1., 1.]]), array([[1230,  325,  278,  712,  123, 1018,  965]], dtype=int64))
# Predicted:  good Data: (3, 2, 1, 2, 1, 1) actual: good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.41421356,
#         1.41421356, 1.41421356]]), array([[  10,  369,  220,  856,  489, 1370, 1177]], dtype=int64))
# Predicted:  good Data: (1, 3, 0, 1, 0, 1) actual: good
# N:  (array([[1., 1., 1., 1., 1., 1., 1.]]), array([[ 543,  378,  187,  251,  303, 1276,  510]], dtype=int64))
# Predicted:  unacc Data: (1, 0, 3, 1, 1, 0) actual: vgood
# N:  (array([[1., 1., 1., 1., 1., 1., 1.]]), array([[  46,   69,  554, 1101,  977,  460, 1129]], dtype=int64))
# Predicted:  good Data: (1, 0, 2, 1, 0, 1) actual: good
# N:  (array([[1., 1., 1., 1., 1., 1., 1.]]), array([[ 928,  469, 1267, 1124,  942, 1175,  799]], dtype=int64))
# Predicted:  good Data: (2, 1, 2, 0, 0, 1) actual: good
# N:  (array([[1., 1., 1., 1., 1., 1., 1.]]), array([[1368,  913, 1260,  183,  851,  197, 1096]], dtype=int64))
# Predicted:  good Data: (1, 3, 0, 0, 1, 2) actual: good
# N:  (array([[1., 1., 1., 1., 1., 1., 1.]]), array([[1067,  624,  210,  670,  777,  879,  240]], dtype=int64))
# Predicted:  good Data: (0, 2, 1, 1, 1, 2) actual: good
# N:  (array([[1., 1., 1., 1., 1., 1., 1.]]), array([[ 888,   68,  249, 1148,  548,  354,  718]], dtype=int64))
# Predicted:  good Data: (3, 1, 1, 1, 2, 2) actual: good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.41421356]]), array([[ 826,  465, 1274,  472, 1380,  373, 1186]], dtype=int64))
# Predicted:  good Data: (1, 3, 2, 0, 2, 2) actual: good
# N:  (array([[1., 1., 1., 1., 1., 1., 1.]]), array([[ 245,  488, 1324, 1303, 1161,  195,  310]], dtype=int64))
# Predicted:  good Data: (3, 3, 2, 1, 0, 2) actual: good
# N:  (array([[1., 1., 1., 1., 1., 1., 1.]]), array([[ 892, 1104,  204, 1123, 1054, 1249, 1359]], dtype=int64))
# Predicted:  good Data: (2, 3, 0, 2, 2, 2) actual: good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.41421356,
#         1.41421356, 1.41421356]]), array([[ 984,  958,  319,  609, 1308,   89, 1033]], dtype=int64))
# Predicted:  good Data: (0, 1, 1, 1, 1, 1) actual: good
# N:  (array([[1., 1., 1., 1., 1., 1., 1.]]), array([[1306,  974, 1111,  613, 1074, 1265,  767]], dtype=int64))
# Predicted:  good Data: (3, 0, 1, 0, 1, 2) actual: good
# N:  (array([[1., 1., 1., 1., 1., 1., 1.]]), array([[1113,  438,  221, 1155,  877, 1186,  328]], dtype=int64))
# Predicted:  good Data: (2, 3, 1, 0, 1, 1) actual: good
# N:  (array([[1., 1., 1., 1., 1., 1., 1.]]), array([[ 989,  938, 1362, 1247,  734, 1179,  946]], dtype=int64))
# Predicted:  good Data: (3, 2, 1, 1, 2, 2) actual: good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.41421356]]), array([[ 707, 1084,  745,  357,  509,  372,  373]], dtype=int64))
# Predicted:  good Data: (2, 3, 0, 0, 1, 1) actual: good
# N:  (array([[1., 1., 1., 1., 1., 1., 1.]]), array([[ 878,  777,  567, 1309, 1328, 1181, 1213]], dtype=int64))
# Predicted:  good Data: (0, 2, 0, 0, 2, 1) actual: good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.41421356]]), array([[1116,  445, 1372,  657,  403,  473,  839]], dtype=int64))
# Predicted:  good Data: (0, 1, 2, 1, 1, 2) actual: unacc
# N:  (array([[1., 1., 1., 1., 1., 1., 1.]]), array([[ 244,  968,  508, 1046, 1074, 1342, 1190]], dtype=int64))
# Predicted:  unacc Data: (2, 3, 2, 2, 1, 0) actual: unacc
# N:  (array([[1., 1., 1., 1., 1., 1., 1.]]), array([[ 549,  700,  551, 1230,  965,  451,  110]], dtype=int64))
# Predicted:  unacc Data: (2, 0, 3, 2, 0, 1) actual: good
# N:  (array([[1., 1., 1., 1., 1., 1., 1.]]), array([[1169,  930,  452,  131, 1048,  382,  168]], dtype=int64))
# Predicted:  good Data: (0, 1, 1, 2, 2, 2) actual: good
# N:  (array([[1., 1., 1., 1., 1., 1., 1.]]), array([[ 873,  385,  239, 1297,  193, 1178,  667]], dtype=int64))
# Predicted:  good Data: (3, 1, 3, 0, 0, 0) actual: good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.41421356]]), array([[ 717,  710, 1141,  689,   47, 1075,  270]], dtype=int64))
# Predicted:  unacc Data: (2, 0, 2, 2, 1, 2) actual: unacc
# N:  (array([[1., 1., 1., 1., 1., 1., 1.]]), array([[423, 416, 341,  27, 281, 922, 420]], dtype=int64))
# Predicted:  good Data: (1, 1, 3, 2, 2, 1) actual: good
# N:  (array([[1., 1., 1., 1., 1., 1., 1.]]), array([[   1,  633, 1134,  730,  699,  180,  302]], dtype=int64))
# Predicted:  good Data: (1, 3, 1, 0, 0, 0) actual: good
# N:  (array([[1., 1., 1., 1., 1., 1., 1.]]), array([[1185,   32,  112,  837,  973,   52,  236]], dtype=int64))
# Predicted:  good Data: (2, 1, 2, 1, 0, 2) actual: acc
# N:  (array([[1., 1., 1., 1., 1., 1., 1.]]), array([[ 964,  111,   13,  291,  913, 1008, 1260]], dtype=int64))
# Predicted:  unacc Data: (2, 2, 0, 1, 0, 2) actual: unacc
# N:  (array([[1., 1., 1., 1., 1., 1., 1.]]), array([[ 532,  178,  337, 1281,  226,  868, 1139]], dtype=int64))
# Predicted:  good Data: (0, 3, 1, 1, 0, 0) actual: good
# N:  (array([[1., 1., 1., 1., 1., 1., 1.]]), array([[  52, 1208,  253, 1082, 1109,  112,  338]], dtype=int64))
# Predicted:  unacc Data: (1, 3, 3, 1, 2, 0) actual: unacc
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.41421356, 1.41421356]]), array([[1094,  750, 1221,  260,  320,   22, 1332]], dtype=int64))
# Predicted:  unacc Data: (3, 2, 1, 2, 1, 2) actual: unacc
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.41421356]]), array([[ 902, 1330,  509,  357, 1377,  441,  373]], dtype=int64))
# Predicted:  good Data: (0, 1, 1, 0, 0, 2) actual: good
# N:  (array([[1., 1., 1., 1., 1., 1., 1.]]), array([[1153,  688,  948, 1363,  602, 1283,  785]], dtype=int64))
# Predicted:  good Data: (3, 2, 2, 0, 0, 2) actual: good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.41421356]]), array([[ 238, 1249, 1154,  444,  575,  779,  705]], dtype=int64))
# Predicted:  good Data: (0, 3, 1, 2, 1, 1) actual: good
# N:  (array([[1., 1., 1., 1., 1., 1., 1.]]), array([[ 92, 861, 486, 304, 576, 555, 177]], dtype=int64))
# Predicted:  good Data: (1, 3, 3, 0, 0, 1) actual: good
# N:  (array([[1.        , 1.        , 1.        , 1.41421356, 1.41421356,
#         1.41421356, 1.41421356]]), array([[1032, 1348, 1344,  153,    4,  562,  101]], dtype=int64))
# Predicted:  unacc Data: (1, 3, 2, 1, 2, 0) actual: unacc
# N:  (array([[1., 1., 1., 1., 1., 1., 1.]]), array([[ 294,  897,   53,  606,  283, 1332, 1244]], dtype=int64))
# Predicted:  good Data: (0, 3, 3, 0, 2, 1) actual: good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.41421356,
#         1.41421356, 1.41421356]]), array([[955, 149, 481, 900, 245, 320, 428]], dtype=int64))
# Predicted:  good Data: (0, 2, 0, 0, 0, 1) actual: good
# N:  (array([[1., 1., 1., 1., 1., 1., 1.]]), array([[370, 492, 334, 570,  28, 219, 445]], dtype=int64))
# Predicted:  good Data: (3, 1, 2, 2, 0, 0) actual: unacc
# N:  (array([[1., 1., 1., 1., 1., 1., 1.]]), array([[1144,  990,  857,  315,  408, 1038,   94]], dtype=int64))
# Predicted:  good Data: (0, 1, 1, 0, 1, 0) actual: good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.41421356]]), array([[ 767,  205, 1290,  978,  613, 1200,  783]], dtype=int64))
# Predicted:  good Data: (0, 0, 1, 0, 0, 1) actual: good
# N:  (array([[1., 1., 1., 1., 1., 1., 1.]]), array([[1283, 1138,  602,  475,  280,  783,  746]], dtype=int64))
# Predicted:  good Data: (3, 2, 2, 2, 2, 1) actual: good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.41421356]]), array([[ 653,  456,  866,  972,  773,   40, 1177]], dtype=int64))
# Predicted:  unacc Data: (3, 1, 1, 2, 0, 2) actual: unacc
# N:  (array([[1., 1., 1., 1., 1., 1., 1.]]), array([[ 498, 1377,  597,  322, 1330, 1045,   83]], dtype=int64))
# Predicted:  good Data: (2, 3, 3, 2, 2, 1) actual: good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.41421356]]), array([[ 559, 1375, 1204,  242,  296,  234,  965]], dtype=int64))
# Predicted:  unacc Data: (3, 1, 1, 1, 1, 0) actual: unacc
# N:  (array([[1., 1., 1., 1., 1., 1., 1.]]), array([[ 788,  969,  905, 1219,  901,  962,   15]], dtype=int64))
# Predicted:  good Data: (0, 3, 3, 1, 2, 0) actual: good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.41421356, 1.41421356]]), array([[283, 368, 479, 900, 628, 738, 428]], dtype=int64))
# Predicted:  good Data: (0, 0, 3, 1, 1, 1) actual: good
# N:  (array([[1., 1., 1., 1., 1., 1., 1.]]), array([[ 807,   69, 1129,  954,  258, 1092,  945]], dtype=int64))
# Predicted:  good Data: (1, 2, 2, 0, 2, 1) actual: good
# N:  (array([[1., 1., 1., 1., 1., 1., 1.]]), array([[ 672,  580,  523,  195, 1303,  173,  222]], dtype=int64))
# Predicted:  good Data: (1, 3, 3, 0, 2, 1) actual: good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.41421356, 1.41421356]]), array([[ 245,  343,  320,  672,  195,  101, 1332]], dtype=int64))
# Predicted:  good Data: (2, 3, 0, 2, 0, 1) actual: good
# N:  (array([[1., 1., 1., 1., 1., 1., 1.]]), array([[ 143,  251,  824, 1023, 1308, 1304,  279]], dtype=int64))
# Predicted:  good Data: (1, 2, 2, 2, 1, 1) actual: good
# N:  (array([[1., 1., 1., 1., 1., 1., 1.]]), array([[1310,  531,  623,  649,  170,   51,  311]], dtype=int64))
# Predicted:  good Data: (0, 2, 2, 1, 2, 2) actual: good
# N:  (array([[1., 1., 1., 1., 1., 1., 1.]]), array([[1212,  244,  735,  490, 1337,   61, 1011]], dtype=int64))
# Predicted:  good Data: (3, 0, 0, 2, 2, 1) actual: good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.41421356]]), array([[1237,  491,   44,  538, 1108,  506, 1058]], dtype=int64))
# Predicted:  unacc Data: (1, 2, 3, 1, 2, 2) actual: unacc
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.41421356]]), array([[1337, 1142,  231,  847,  871,  147,  391]], dtype=int64))
# Predicted:  good Data: (3, 3, 1, 1, 2, 2) actual: good
# N:  (array([[1., 1., 1., 1., 1., 1., 1.]]), array([[  73,  507,  641,  836, 1358,  297, 1150]], dtype=int64))
# Predicted:  good Data: (0, 3, 0, 0, 2, 1) actual: good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.41421356]]), array([[ 841,  459,  501,  622, 1350,  248,  240]], dtype=int64))
# Predicted:  good Data: (1, 1, 1, 2, 1, 1) actual: good
# N:  (array([[1., 1., 1., 1., 1., 1., 1.]]), array([[1207,   23,  353,   62,  974,  360, 1306]], dtype=int64))
# Predicted:  good Data: (1, 1, 1, 0, 0, 0) actual: good
# N:  (array([[1., 1., 1., 1., 1., 1., 1.]]), array([[ 480, 1185,   64, 1259,  229,  978,  638]], dtype=int64))
# Predicted:  good Data: (3, 3, 2, 0, 1, 1) actual: good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.41421356, 1.41421356]]), array([[1288, 1247,  619,  797,  216,  144, 1112]], dtype=int64))
# Predicted:  good Data: (3, 0, 0, 1, 0, 1) actual: good
# N:  (array([[1., 1., 1., 1., 1., 1., 1.]]), array([[1239,  557,  285, 1133, 1269,  920,   77]], dtype=int64))
# Predicted:  good Data: (0, 2, 3, 1, 1, 1) actual: good
# N:  (array([[1., 1., 1., 1., 1., 1., 1.]]), array([[ 572, 1044, 1364,  907,   91,    5,  289]], dtype=int64))
# Predicted:  good Data: (2, 1, 0, 2, 1, 1) actual: good
# N:  (array([[1., 1., 1., 1., 1., 1., 1.]]), array([[ 637,  917,  794,  489, 1025,   26,  326]], dtype=int64))
# Predicted:  unacc Data: (3, 2, 0, 1, 0, 0) actual: unacc
# N:  (array([[1., 1., 1., 1., 1., 1., 1.]]), array([[1205,  725,  632,  105,  132,  256, 1341]], dtype=int64))
# Predicted:  good Data: (1, 0, 1, 2, 1, 1) actual: good
# N:  (array([[1., 1., 1., 1., 1., 1., 1.]]), array([[ 616,  346,  115,  822, 1224,  776,  825]], dtype=int64))
# Predicted:  good Data: (1, 3, 3, 1, 0, 1) actual: good
# N:  (array([[1., 1., 1., 1., 1., 1., 1.]]), array([[ 947,  141,  163,  662,  153, 1055, 1272]], dtype=int64))
# Predicted:  unacc Data: (1, 3, 0, 2, 2, 0) actual: good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.41421356, 1.41421356]]), array([[ 209,  409, 1006,  753,  842,  228,   95]], dtype=int64))
# Predicted:  good Data: (2, 3, 2, 1, 1, 2) actual: unacc
# N:  (array([[1., 1., 1., 1., 1., 1., 1.]]), array([[1104,  314,  461,   60, 1361,  386, 1234]], dtype=int64))
# Predicted:  good Data: (3, 2, 0, 0, 2, 1) actual: good
# N:  (array([[1., 1., 1., 1., 1., 1., 1.]]), array([[ 981,  697,  959,   35,  225, 1326,  715]], dtype=int64))
# Predicted:  good Data: (2, 3, 2, 0, 0, 1) actual: good
# N:  (array([[1., 1., 1., 1., 1., 1., 1.]]), array([[1247, 1286, 1095, 1348, 1210,  358,  989]], dtype=int64))
# Predicted:  good Data: (3, 3, 2, 0, 1, 0) actual: good
# N:  (array([[1., 1., 1., 1., 1., 1., 1.]]), array([[ 882,  719,  993,  190,  584,  749, 1112]], dtype=int64))
# Predicted:  good Data: (2, 2, 2, 2, 2, 1) actual: good
# N:  (array([[1., 1., 1., 1., 1., 1., 1.]]), array([[ 559,  561,  203, 1204,  159, 1370,  995]], dtype=int64))
# Predicted:  good Data: (3, 3, 2, 0, 0, 1) actual: good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.41421356, 1.41421356]]), array([[ 931, 1359,  575, 1030,  993, 1090,  618]], dtype=int64))
# Predicted:  good Data: (3, 3, 3, 0, 2, 1) actual: good
# N:  (array([[1., 1., 1., 1., 1., 1., 1.]]), array([[997, 343, 216,  90, 709, 757, 619]], dtype=int64))
# Predicted:  good Data: (1, 2, 1, 1, 1, 1) actual: good
# N:  (array([[1., 1., 1., 1., 1., 1., 1.]]), array([[ 354,  591, 1140,  182,  727,  249,  293]], dtype=int64))
# Predicted:  good Data: (1, 2, 2, 1, 0, 0) actual: vgood
# N:  (array([[1., 1., 1., 1., 1., 1., 1.]]), array([[ 401,  915,  673, 1146,  601, 1012, 1004]], dtype=int64))
# Predicted:  good Data: (0, 0, 2, 2, 2, 2) actual: good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.41421356]]), array([[ 667, 1178, 1233,  885,  909,  442, 1078]], dtype=int64))
# Predicted:  unacc Data: (3, 1, 3, 2, 1, 2) actual: unacc
# N:  (array([[1., 1., 1., 1., 1., 1., 1.]]), array([[ 516,   18,  809,  344,  107, 1013, 1287]], dtype=int64))
# Predicted:  good Data: (2, 3, 1, 0, 1, 0) actual: good
# N:  (array([[1., 1., 1., 1., 1., 1., 1.]]), array([[ 567,  973, 1112,  719,   32,  359,  607]], dtype=int64))
